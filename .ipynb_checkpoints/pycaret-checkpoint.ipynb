# %%
# %pip install pycaret 
# %pip install pycaret[models]
# %pip install cuml
from lightgbm import*
from pandas import*
from datetime import datetime
from numpy import*
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from lightgbm import*
# We'll also import seaborn, a Python graphing library
import warnings # current version of seaborn generates a bunch of warnings that we'll ignore
warnings.filterwarnings("ignore")
import seaborn as sns
sns.set(style="white", color_codes=True)
# Out:
# Requirement already satisfied: pycaret in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (3.0.0rc4)
# Requirement already satisfied: matplotlib>=3.3.0 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (3.4.3)
# Requirement already satisfied: importlib-metadata>=4.12.0 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (5.0.0)
# Requirement already satisfied: imbalanced-learn>=0.8.1 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (0.9.0)
# Requirement already satisfied: numba~=0.55.0 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (0.55.2)
# Requirement already satisfied: category-encoders>=2.4.0 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (2.5.1.post0)
# Requirement already satisfied: yellowbrick>=1.4 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (1.4)
# Requirement already satisfied: pmdarima!=1.8.1,<2.0.0,>=1.8.0 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (1.8.5)
# Requirement already satisfied: psutil>=5.9.0 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (5.9.2)
# Requirement already satisfied: jinja2>=1.2 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (3.1.2)
# Requirement already satisfied: tbats>=1.1.0 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (1.1.1)
# Requirement already satisfied: plotly>=5.0.0 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (5.5.0)
# Requirement already satisfied: lightgbm>=3.0.0 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (3.3.2)
# Requirement already satisfied: scikit-plot>=0.3.7 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (0.3.7)
# Requirement already satisfied: scipy<1.9.0 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (1.8.1)
# Requirement already satisfied: pandas<1.5.0,>=1.3.0 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (1.4.4)
# Requirement already satisfied: tqdm>=4.62.0 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (4.62.3)
# Requirement already satisfied: joblib>=1.1.0 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (1.1.0)
# Requirement already satisfied: kaleido>=0.2.1 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (0.2.1)
# Requirement already satisfied: ipywidgets>=7.6.5 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (7.6.5)
# Requirement already satisfied: markupsafe>=2.0.1 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (2.1.1)
# Requirement already satisfied: sktime~=0.13.2 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (0.13.4)
# Requirement already satisfied: pyod>=0.9.8 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (1.0.5)
# Requirement already satisfied: statsmodels>=0.12.1 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (0.13.2)
# Requirement already satisfied: numpy<1.23,>=1.21 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (1.22.4)
# Requirement already satisfied: scikit-learn>=1.0 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (1.0.2)
# Requirement already satisfied: requests>=2.27.1 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (2.28.1)
# Requirement already satisfied: ipython>=5.5.0 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (7.29.0)
# Requirement already satisfied: schemdraw>=0.14 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (0.15)
# Requirement already satisfied: plotly-resampler>=0.7.2.2 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from pycaret) (0.8.2rc3)
# Requirement already satisfied: patsy>=0.5.1 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from category-encoders>=2.4.0->pycaret) (0.5.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from imbalanced-learn>=0.8.1->pycaret) (2.2.0)
# Requirement already satisfied: zipp>=0.5 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from importlib-metadata>=4.12.0->pycaret) (3.6.0)
# Requirement already satisfied: setuptools>=18.5 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret) (58.0.4)
# Requirement already satisfied: appnope in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret) (0.1.2)
# Requirement already satisfied: pickleshare in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret) (5.1.0)
# Requirement already satisfied: pexpect>4.3 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret) (4.8.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret) (3.0.20)
# Requirement already satisfied: jedi>=0.16 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret) (0.18.0)
# Requirement already satisfied: backcall in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret) (0.2.0)
# Requirement already satisfied: decorator in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret) (5.1.0)
# Requirement already satisfied: matplotlib-inline in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret) (0.1.2)
# Requirement already satisfied: pygments in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from ipython>=5.5.0->pycaret) (2.10.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.6.5->pycaret) (3.5.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.6.5->pycaret) (1.0.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.6.5->pycaret) (0.2.0)
# Requirement already satisfied: nbformat>=4.2.0 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.6.5->pycaret) (5.1.3)
# Requirement already satisfied: ipykernel>=4.5.1 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from ipywidgets>=7.6.5->pycaret) (6.4.1)
# Requirement already satisfied: jupyter-client<8.0 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (6.1.12)
# Requirement already satisfied: tornado<7.0,>=4.2 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (6.1)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (1.4.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from jedi>=0.16->ipython>=5.5.0->pycaret) (0.8.2)
# Requirement already satisfied: jupyter-core>=4.6.0 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (4.8.1)
# Requirement already satisfied: python-dateutil>=2.1 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (2.8.2)
# Requirement already satisfied: pyzmq>=13 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (22.2.1)
# Requirement already satisfied: wheel in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from lightgbm>=3.0.0->pycaret) (0.37.0)
# Requirement already satisfied: cycler>=0.10 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.3.0->pycaret) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.3.0->pycaret) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.3.0->pycaret) (1.3.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.3.0->pycaret) (8.4.0)
# Requirement already satisfied: six in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from cycler>=0.10->matplotlib>=3.3.0->pycaret) (1.16.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from nbformat>=4.2.0->ipywidgets>=7.6.5->pycaret) (3.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.6.5->pycaret) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.6.5->pycaret) (21.2.0)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from numba~=0.55.0->pycaret) (0.38.1)
# Requirement already satisfied: pytz>=2020.1 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from pandas<1.5.0,>=1.3.0->pycaret) (2021.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from pexpect>4.3->ipython>=5.5.0->pycaret) (0.7.0)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from plotly>=5.0.0->pycaret) (8.0.1)
# Requirement already satisfied: orjson<4.0.0,>=3.7.7 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from plotly-resampler>=0.7.2.2->pycaret) (3.8.0)
# Requirement already satisfied: jupyter-dash>=0.4.2 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from plotly-resampler>=0.7.2.2->pycaret) (0.4.2)
# Requirement already satisfied: dash<3.0.0,>=2.2.0 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from plotly-resampler>=0.7.2.2->pycaret) (2.6.2)
# Requirement already satisfied: Flask-Cors<4.0.0,>=3.0.10 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from plotly-resampler>=0.7.2.2->pycaret) (3.0.10)
# Requirement already satisfied: trace-updater>=0.0.8 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from plotly-resampler>=0.7.2.2->pycaret) (0.0.8)
# Requirement already satisfied: Flask>=1.0.4 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.7.2.2->pycaret) (2.2.2)
# Requirement already satisfied: dash-core-components==2.0.0 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.7.2.2->pycaret) (2.0.0)
# Requirement already satisfied: dash-html-components==2.0.0 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.7.2.2->pycaret) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.7.2.2->pycaret) (5.0.0)
# Requirement already satisfied: flask-compress in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from dash<3.0.0,>=2.2.0->plotly-resampler>=0.7.2.2->pycaret) (1.13)
# Requirement already satisfied: click>=8.0 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from Flask>=1.0.4->dash<3.0.0,>=2.2.0->plotly-resampler>=0.7.2.2->pycaret) (8.0.3)
# Requirement already satisfied: Werkzeug>=2.2.2 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from Flask>=1.0.4->dash<3.0.0,>=2.2.0->plotly-resampler>=0.7.2.2->pycaret) (2.2.2)
# Requirement already satisfied: itsdangerous>=2.0 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from Flask>=1.0.4->dash<3.0.0,>=2.2.0->plotly-resampler>=0.7.2.2->pycaret) (2.0.1)
# Requirement already satisfied: retrying in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from jupyter-dash>=0.4.2->plotly-resampler>=0.7.2.2->pycaret) (1.3.3)
# Requirement already satisfied: ansi2html in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from jupyter-dash>=0.4.2->plotly-resampler>=0.7.2.2->pycaret) (1.8.0)
# Requirement already satisfied: nest-asyncio in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from jupyter-dash>=0.4.2->plotly-resampler>=0.7.2.2->pycaret) (1.5.1)
# Requirement already satisfied: Cython!=0.29.18,>=0.29 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from pmdarima!=1.8.1,<2.0.0,>=1.8.0->pycaret) (0.29.24)
# Requirement already satisfied: urllib3 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from pmdarima!=1.8.1,<2.0.0,>=1.8.0->pycaret) (1.26.7)
# Requirement already satisfied: wcwidth in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.5.0->pycaret) (0.2.5)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.27.1->pycaret) (2021.10.8)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.27.1->pycaret) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from requests>=2.27.1->pycaret) (3.2)
# Requirement already satisfied: deprecated>=1.2.13 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from sktime~=0.13.2->pycaret) (1.2.13)
# Requirement already satisfied: wrapt<2,>=1.10 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from deprecated>=1.2.13->sktime~=0.13.2->pycaret) (1.12.1)
# Requirement already satisfied: packaging>=21.3 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from statsmodels>=0.12.1->pycaret) (21.3)
# Requirement already satisfied: notebook>=4.4.1 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (6.4.5)
# Requirement already satisfied: Send2Trash>=1.5.0 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (1.8.0)
# Requirement already satisfied: prometheus-client in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.11.0)
# Requirement already satisfied: argon2-cffi in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (20.1.0)
# Requirement already satisfied: nbconvert in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (6.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.9.4)
# Requirement already satisfied: cffi>=1.0.0 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (1.14.6)
# Requirement already satisfied: pycparser in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (2.20)
# Requirement already satisfied: brotli in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from flask-compress->dash<3.0.0,>=2.2.0->plotly-resampler>=0.7.2.2->pycaret) (1.0.9)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (1.4.3)
# Requirement already satisfied: jupyterlab-pygments in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.1.2)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.5.3)
# Requirement already satisfied: bleach in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (4.0.0)
# Requirement already satisfied: entrypoints>=0.2.2 in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.3)
# Requirement already satisfied: testpath in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.5.0)
# Requirement already satisfied: defusedxml in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.7.1)
# Requirement already satisfied: async-generator in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (1.10)
# Requirement already satisfied: webencodings in /Users/sage/opt/anaconda3/lib/python3.9/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.5.1)
# Note: you may need to restart the kernel to use updated packages.
# zsh:1: no matches found: pycaret[models]
# Note: you may need to restart the kernel to use updated packages.
# Collecting cuml
#   Using cached cuml-0.6.1.post1.tar.gz (1.1 kB)
# Building wheels for collected packages: cuml
#   Building wheel for cuml (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /Users/sage/opt/anaconda3/bin/python -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/sg/8dmzq1nn0wl6qmndt2sf_m1r0000gn/T/pip-install-2hx5ouv2/cuml_123a75db01a04076a74a2ecd46a59a8a/setup.py'"'"'; __file__='"'"'/private/var/folders/sg/8dmzq1nn0wl6qmndt2sf_m1r0000gn/T/pip-install-2hx5ouv2/cuml_123a75db01a04076a74a2ecd46a59a8a/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /private/var/folders/sg/8dmzq1nn0wl6qmndt2sf_m1r0000gn/T/pip-wheel-shgb6pcl
#        cwd: /private/var/folders/sg/8dmzq1nn0wl6qmndt2sf_m1r0000gn/T/pip-install-2hx5ouv2/cuml_123a75db01a04076a74a2ecd46a59a8a/
#   Complete output (25 lines):
#   running bdist_wheel
#   running build
#   installing to build/bdist.macosx-10.9-x86_64/wheel
#   running install
#   Traceback (most recent call last):
#     File "<string>", line 1, in <module>
#     File "/private/var/folders/sg/8dmzq1nn0wl6qmndt2sf_m1r0000gn/T/pip-install-2hx5ouv2/cuml_123a75db01a04076a74a2ecd46a59a8a/setup.py", line 18, in <module>
#       setup(name=pkg,
#     File "/Users/sage/opt/anaconda3/lib/python3.9/site-packages/setuptools/__init__.py", line 153, in setup
#       return distutils.core.setup(**attrs)
#     File "/Users/sage/opt/anaconda3/lib/python3.9/distutils/core.py", line 148, in setup
#       dist.run_commands()
#     File "/Users/sage/opt/anaconda3/lib/python3.9/distutils/dist.py", line 966, in run_commands
#       self.run_command(cmd)
#     File "/Users/sage/opt/anaconda3/lib/python3.9/distutils/dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "/Users/sage/opt/anaconda3/lib/python3.9/site-packages/wheel/bdist_wheel.py", line 335, in run
#       self.run_command('install')
#     File "/Users/sage/opt/anaconda3/lib/python3.9/distutils/cmd.py", line 313, in run_command
#       self.distribution.run_command(command)
#     File "/Users/sage/opt/anaconda3/lib/python3.9/distutils/dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "/private/var/folders/sg/8dmzq1nn0wl6qmndt2sf_m1r0000gn/T/pip-install-2hx5ouv2/cuml_123a75db01a04076a74a2ecd46a59a8a/setup.py", line 15, in run
#       raise Exception(long_description)
#   Exception: Please install cuml via the rapidsai conda channel. See https://rapids.ai/start.html for instructions.
#   ----------------------------------------
#   ERROR: Failed building wheel for cuml
#   Running setup.py clean for cuml
# Failed to build cuml
# Installing collected packages: cuml
#     Running setup.py install for cuml ... error
#     ERROR: Command errored out with exit status 1:
#      command: /Users/sage/opt/anaconda3/bin/python -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/sg/8dmzq1nn0wl6qmndt2sf_m1r0000gn/T/pip-install-2hx5ouv2/cuml_123a75db01a04076a74a2ecd46a59a8a/setup.py'"'"'; __file__='"'"'/private/var/folders/sg/8dmzq1nn0wl6qmndt2sf_m1r0000gn/T/pip-install-2hx5ouv2/cuml_123a75db01a04076a74a2ecd46a59a8a/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /private/var/folders/sg/8dmzq1nn0wl6qmndt2sf_m1r0000gn/T/pip-record-dcw9slln/install-record.txt --single-version-externally-managed --compile --install-headers /Users/sage/opt/anaconda3/include/python3.9/cuml
#          cwd: /private/var/folders/sg/8dmzq1nn0wl6qmndt2sf_m1r0000gn/T/pip-install-2hx5ouv2/cuml_123a75db01a04076a74a2ecd46a59a8a/
#     Complete output (16 lines):
#     running install
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/private/var/folders/sg/8dmzq1nn0wl6qmndt2sf_m1r0000gn/T/pip-install-2hx5ouv2/cuml_123a75db01a04076a74a2ecd46a59a8a/setup.py", line 18, in <module>
#         setup(name=pkg,
#       File "/Users/sage/opt/anaconda3/lib/python3.9/site-packages/setuptools/__init__.py", line 153, in setup
#         return distutils.core.setup(**attrs)
#       File "/Users/sage/opt/anaconda3/lib/python3.9/distutils/core.py", line 148, in setup
#         dist.run_commands()
#       File "/Users/sage/opt/anaconda3/lib/python3.9/distutils/dist.py", line 966, in run_commands
#         self.run_command(cmd)
#       File "/Users/sage/opt/anaconda3/lib/python3.9/distutils/dist.py", line 985, in run_command
#         cmd_obj.run()
#       File "/private/var/folders/sg/8dmzq1nn0wl6qmndt2sf_m1r0000gn/T/pip-install-2hx5ouv2/cuml_123a75db01a04076a74a2ecd46a59a8a/setup.py", line 15, in run
#         raise Exception(long_description)
#     Exception: Please install cuml via the rapidsai conda channel. See https://rapids.ai/start.html for instructions.
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: /Users/sage/opt/anaconda3/bin/python -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/sg/8dmzq1nn0wl6qmndt2sf_m1r0000gn/T/pip-install-2hx5ouv2/cuml_123a75db01a04076a74a2ecd46a59a8a/setup.py'"'"'; __file__='"'"'/private/var/folders/sg/8dmzq1nn0wl6qmndt2sf_m1r0000gn/T/pip-install-2hx5ouv2/cuml_123a75db01a04076a74a2ecd46a59a8a/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /private/var/folders/sg/8dmzq1nn0wl6qmndt2sf_m1r0000gn/T/pip-record-dcw9slln/install-record.txt --single-version-externally-managed --compile --install-headers /Users/sage/opt/anaconda3/include/python3.9/cuml Check the logs for full command output.
# Note: you may need to restart the kernel to use updated packages.
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /var/folders/sg/8dmzq1nn0wl6qmndt2sf_m1r0000gn/T/ipykernel_34953/886475183.py in <module>
#       2 get_ipython().run_line_magic('pip', 'install pycaret[models]')
#       3 get_ipython().run_line_magic('pip', 'install cuml')
# ----> 4 from lightgbm import*
#       5 from pandas import*
#       6 from datetime import datetime
#
# ~/opt/anaconda3/lib/python3.9/site-packages/lightgbm/__init__.py in <module>
#       6 from pathlib import Path
#       7
# ----> 8 from .basic import Booster, Dataset, Sequence, register_logger
#       9 from .callback import early_stopping, log_evaluation, print_evaluation, record_evaluation, reset_parameter
#      10 from .engine import CVBooster, cv, train
#
# ~/opt/anaconda3/lib/python3.9/site-packages/lightgbm/basic.py in <module>
#     108
#     109
# --> 110 _LIB = _load_lib()
#     111
#     112
#
# ~/opt/anaconda3/lib/python3.9/site-packages/lightgbm/basic.py in _load_lib()
#      99     if len(lib_path) == 0:
#     100         return None
# --> 101     lib = ctypes.cdll.LoadLibrary(lib_path[0])
#     102     lib.LGBM_GetLastError.restype = ctypes.c_char_p
#     103     callback = ctypes.CFUNCTYPE(None, ctypes.c_char_p)
#
# ~/opt/anaconda3/lib/python3.9/ctypes/__init__.py in LoadLibrary(self, name)
#     458
#     459     def LoadLibrary(self, name):
# --> 460         return self._dlltype(name)
#     461
#     462     __class_getitem__ = classmethod(_types.GenericAlias)
#
# ~/opt/anaconda3/lib/python3.9/ctypes/__init__.py in __init__(self, name, mode, handle, use_errno, use_last_error, winmode)
#     380
#     381         if handle is None:
# --> 382             self._handle = _dlopen(self._name, mode)
#     383         else:
#     384             self._handle = handle
#
# OSError: dlopen(/Users/sage/opt/anaconda3/lib/python3.9/site-packages/lightgbm/lib_lightgbm.so, 0x0006): Library not loaded: '/usr/local/opt/libomp/lib/libomp.dylib'
#   Referenced from: '/Users/sage/opt/anaconda3/lib/python3.9/site-packages/lightgbm/lib_lightgbm.so'
#   Reason: tried: '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/lib/libomp.dylib' (no such file), '/usr/lib/libomp.dylib' (no such file)

# %%
# load dataset
from pycaret.datasets import get_data
insurance = get_data('insurance')

# init environment
from pycaret.regression import *
r1 = setup(insurance,
           target = 'charges',
           session_id = 122,
           normalize = True
           polynomial_features = True,
           trigonometry_features = True,
           feature_interaction=True,
           bin_numeric_features= ['age', 'bmi']
          )
#Model training and selection
best_lr= compare_models()

# Analyse best model
evaluate_model(best_lr)

# predictions on new data
predictions = predict_models(best_lr)

# save pipeline/model
save_model(best_lr,'MLOps_Pipeline')
